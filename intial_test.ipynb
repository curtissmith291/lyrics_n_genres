# %% [markdown]
# ## Initial test for determining viability for long list of songs

# %%
# Import Dependencies
import requests
import lyricsgenius
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
import re

# Import Access Tokens and Credentials
from config import genius_token, spotify_id, spotify_secret

# %%
# Import list of songs
test_df = pd.read_csv("song_files/combined.csv")

# %%
test_df.head()
# Out:
#                    Song              Artist
# 0          Satisfaction  The Rolling Stones
# 1               Respect     Aretha Franklin
# 2    Stairway to Heaven        Led Zeppelin
# 3  Like a Rolling Stone           Bob Dylan
# 4           Born to Run   Bruce Springsteen

# %%
# Rename columns to match copdied code from "proof of concept"
test_df.columns = ["song", "artist"]

# %%
# Convert dataframe to list of dictionaries
input_list = test_df.to_dict('records')

# %% [markdown]
# ### API Step 1: Get Lyrics from Genius

# %%
# Initialize lyricgenius Class
genius = lyricsgenius.Genius(genius_token)

# %%
# Remove section headers (e.g. [Chorus]) from lyrics when searching
genius.remove_section_headers = True

# %%
# Initialize Results List and Error List
results = []
errors = []

# Retrieve Song Lyrics

start = time.time()

for item in input_list:
    try:
        song = genius.search_song(item["song"], artist = item["artist"])
        temp_dict = {"song":item["song"],
                     "artist": item["artist"],
                     "genius_artist": song.artist,
                     "spotify_artist": "",
                     "artist_id": "",
                     "album": "",
                     "artist_genre(s)":[], 
                     "lyrics": song.lyrics,
                     "audio_features": {}
                    } 
        results.append(temp_dict)
    except:
        temp_dict = {"song":item["song"],
                     "artist": item["artist"],
                     "lyrics": "null"
                    }
        errors.append(temp_dict)
print("finished")
duration = time.time() - start
print(f'Ran in {duration} seconds/{duration/60} minutes')
print(f'There were {len(errors)} errors')
# Out:
# Searching for "Satisfaction" by The Rolling Stones...
# Done.
# Searching for "Respect" by Aretha Franklin...
# Done.
# Searching for "Stairway to Heaven" by Led Zeppelin...
# Done.
# Searching for "Like a Rolling Stone" by Bob Dylan...
# Done.
# Searching for "Born to Run" by Bruce Springsteen...
# Done.
# Searching for "Hotel California" by The Eagles...
# Done.
# Searching for "Light My Fire" by The Doors...
# Done.
# Searching for "Good Vibrations" by The Beach Boys...
# Done.
# Searching for "Hey Jude" by The Beatles...
# Done.
# Searching for "Imagine" by John Lennon...
# Done.
# Searching for "Louie Louie" by The Kingsmen...
# Done.
# Searching for "Yesterday" by The Beatles...
# Done.
# Searching for "My Generation" by The Who...
# Done.
# Searching for "What's Going On" by Marvin Gaye...
# Done.
# Searching for "Johnny B. Goode" by Chuck Berry...
# Done.
# Searching for "Layla" by Derek & The Dominos...
# Done.
# Searching for "Won't Get Fooled Again" by The Who...
# Done.
# Searching for "Jailhouse Rock" by Elvis Presley...
# Done.
# Searching for "American Pie" by Don McLean...
# Done.
# Searching for "A Day in the Life" by The Beatles...
# Done.
# Searching for "I Got You (I Feel Good)" by James Brown...
# Done.
# Searching for "Superstition" by Stevie Wonder...
# Done.
# Searching for "I Want to Hold Your Hand" by The Beatles...
# Done.
# Searching for "Brown Sugar" by The Rolling Stones...
# Done.
# Searching for "Purple Haze" by Jimi Hendrix...
# Done.
# Searching for "Sympathy for the Devil" by The Rolling Stones...
# Done.
# Searching for "Flowers on the Wall" by The Statler Brothers...
# Done.
# Searching for "Strawberry Wine" by Deana Carter...
# Done.
# Searching for "Good Hearted Woman" by Waylon Jennings & Willie Nelson...
# Done.
# Searching for "You're Still the One" by Shania Twain...
# Done.
# Searching for "My Home's in Alabama" by Alabama...
# Done.
# Searching for "Is There Life Out There" by Reba Mcentire...
# Done.
# Searching for "She's in Love With the Boy" by Trisha Yearwood...
# Done.
# Searching for "Smoky Mountain Rain" by Ronnie Milsap...
# Done.
# Searching for "Should've Been a Cowboy" by Toby Keith...
# Done.
# Searching for "Rose Garden" by Lynn Anderson...
# Done.
# Searching for "Please Remember Me" by Tim McGraw...
# Done.
# Searching for "Blue" by LeAnn Rimes...
# Done.
# Searching for "Before the Next Teardrop Falls" by Freddy Fender...
# Done.
# Searching for "Passionate Kisses" by Mary Chapin Carpenter...
# Done.
# Searching for "Have I Told You Lately That I Love You" by Gene Autry...
# Done.
# Searching for "Here's a Quarter (Call Someone Who Cares)" by Travis Tritt...
# Done.
# Searching for "He'll Have to Go" by Jim Reeves...
# Done.
# Searching for "Seven Year Ache" by Rosanne Cash...
# Done.
# Searching for "Sunday Mornin' Comin' Down" by Johnny Cash or Kris Kristofferson...
# Done.
# Searching for "Take This Job And Shove It" by Johnny Paycheck...
# Done.
# Searching for "Something in Red" by Lorrie Morgan...
# Done.
# Searching for "Foggy Mountain Breakdown" by Flatt & Scruggs...
# Specified song does not contain lyrics. Rejecting.
# Searching for "I'D Be Better Off (In a Pine Box)" by Doug Stone...
# Done.
# Searching for "Amazed" by Lonestar...
# Done.
# Searching for "Faded Love" by Bob Wills or Patsy Cline...
# Done.
# Searching for "Back in the Saddle Again" by Gene Autry...
# Done.
# Searching for "Killin' Time" by Clint Black...
# Done.
# finished
# Ran in 514.2927451133728 seconds/8.571545751889547 minutes
# There were 12 errors

# %% [markdown]
# ### API Step 2: Get Artist ID from Spotify

# %%
# Initialize Spotipy Class
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=spotify_id, client_secret=spotify_secret))

# %%
# Iterate through results add artist Spotify ID

start = time.time()

artist_search_errors = []

for item in results:
    
    try:
        sp_result = sp.search(item["artist"])

        artist_results = sp_result['tracks']['items']
        
        counter = 1
        for i in artist_results:
            spotify_artist = i["album"]["artists"][0]["name"]
            artist_id = i["album"]["artists"][0]["id"]
            
            # Creating different case/and .vs & artist strings; artist names not always consistant 
            genius_lower = item["genius_artist"].lower()
            genius_ampersand = re.sub('and', '&', genius_lower)
            genius_and = re.sub('&', 'and', genius_lower)           
            
            artist_lower = item["artist"].lower()
            artist_ampersand = re.sub('and', '&', artist_lower)
            artist_and = re.sub('&', 'and', artist_lower)
            
            artist_test_list = []
            artist_test_list.extend([genius_lower, genius_ampersand, genius_and, 
                                     artist_lower, artist_ampersand, artist_and])
            
#             if spotify_artist.lower() == artist_lower or spotify_artist.lower() == artist_ampersand or spotify_artist.lower() == artist_and:
            if spotify_artist.lower() in artist_test_list:
                item["artist_id"]=artist_id
                item["spotify_artist"]=spotify_artist
#                 print(spotify_artist, item["artist"])
                break
            
            elif counter == len(artist_results):
                artist_search_errors.append(item["artist"])
            
            else:
                print(f'Search Artist: {item["artist"]}, Spotify Artist: {spotify_artist}')
                counter += 1
    
    except:
        # print(f"yikes, an error happened with {item['artist']}")
        artist_search_errors.append(item["artist"])
    
print("finished")
duration = time.time() - start
print(f'Ran in {duration} seconds/{duration/60} minutes')
print(f'There were {len(artist_search_errors)} errors')
# Out:
# Search Artist: Bob Dylan, Spotify Artist: Fall Out Boy
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: The Eagles, Spotify Artist: Eagles
# Search Artist: James Brown, Spotify Artist: SNBRN
# Search Artist: Queen, Spotify Artist: Red Velvet
# Search Artist: Queen, Spotify Artist: Megan Thee Stallion
# Search Artist: Queen, Spotify Artist: Loren Gray
# Search Artist: Ray Charles, Spotify Artist: Third World Don
# Search Artist: Buddy Holly, Spotify Artist: Weezer
# Search Artist: Buddy Holly, Spotify Artist: Various Artists
# Search Artist: Bob Dylan, Spotify Artist: Fall Out Boy
# Search Artist: David Bowie, Spotify Artist: Queen
# Search Artist: Rod Stewart, Spotify Artist: A$AP Rocky
# Search Artist: Cream, Spotify Artist: Roddy Ricch
# Search Artist: Cream, Spotify Artist: Key Glock
# Search Artist: Cream, Spotify Artist: Zotiyac
# Search Artist: Carl Perkins, Spotify Artist: Drive-By Truckers
# Search Artist: Boston, Spotify Artist: Augustana
# Search Artist: Queen, Spotify Artist: Red Velvet
# Search Artist: Queen, Spotify Artist: Megan Thee Stallion
# Search Artist: Queen, Spotify Artist: Loren Gray
# Search Artist: Bob Dylan, Spotify Artist: Fall Out Boy
# Search Artist: Prince, Spotify Artist: ilyTOMMY
# Search Artist: Prince, Spotify Artist: Ashnikko
# Search Artist: Prince, Spotify Artist: Annapantsu
# Search Artist: Prince, Spotify Artist: CARYS
# Search Artist: Prince, Spotify Artist: Hot Freaks
# Search Artist: Prince, Spotify Artist: TOPHAMHAT-KYO
# Search Artist: Prince, Spotify Artist: Various Artists
# Search Artist: Prince, Spotify Artist: TOPHAMHAT-KYO
# Search Artist: Prince, Spotify Artist: King Princess
# Search Artist: Black Flag, Spotify Artist: HELLYEAH
# Search Artist: Black Flag, Spotify Artist: Various Artists
# Search Artist: Black Flag, Spotify Artist: Dirty
# Search Artist: Dead Boys, Spotify Artist: Sam Fender
# Search Artist: Dead Boys, Spotify Artist: $uicideboy$
# Search Artist: Dead Boys, Spotify Artist: Powerwolf
# Search Artist: Dead Boys, Spotify Artist: Colter Wall
# Search Artist: MC5, Spotify Artist: Stone Temple Pilots
# Search Artist: MC5, Spotify Artist: MC Davo
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Richard Hell & the Voidoids, Spotify Artist: Richard Hell
# Search Artist: Wire, Spotify Artist: The Neighbourhood
# Search Artist: Wire, Spotify Artist: Kanye West
# Search Artist: Wire, Spotify Artist: Worthikids
# Search Artist: Wire, Spotify Artist: Sonny Fodera
# Search Artist: Wire, Spotify Artist: Far East Movement
# Search Artist: Wire, Spotify Artist: Meisa Kuroki
# Search Artist: Wire, Spotify Artist: SiR
# Search Artist: Wire, Spotify Artist: HAIM
# Search Artist: Wire, Spotify Artist: Far East Movement
# Search Artist: The Heartbreakers, Spotify Artist: Tom Petty and the Heartbreakers
# Search Artist: The Heartbreakers, Spotify Artist: Stevie Nicks
# Search Artist: The Heartbreakers, Spotify Artist: Tom Petty and the Heartbreakers
# Search Artist: The Heartbreakers, Spotify Artist: Tom Petty and the Heartbreakers
# Search Artist: The Heartbreakers, Spotify Artist: Tom Petty and the Heartbreakers
# Search Artist: The Heartbreakers, Spotify Artist: Tom Petty and the Heartbreakers
# Search Artist: The Heartbreakers, Spotify Artist: Tom Petty and the Heartbreakers
# Search Artist: The Heartbreakers, Spotify Artist: Stevie Nicks
# Search Artist: The Heartbreakers, Spotify Artist: Tom Petty and the Heartbreakers
# Search Artist: The Misfits, Spotify Artist: Diabulus in Musica
# Search Artist: The Misfits, Spotify Artist: DREAMERS
# Search Artist: The Misfits, Spotify Artist: Misfits
# Search Artist: The Misfits, Spotify Artist: Misfits
# Search Artist: The Misfits, Spotify Artist: Misfits
# Search Artist: The Misfits, Spotify Artist: Misfits
# Search Artist: The Misfits, Spotify Artist: Misfits
# Search Artist: The Misfits, Spotify Artist: Misfits
# Search Artist: The Misfits, Spotify Artist: Misfits
# Search Artist: The Jam, Spotify Artist: Logic
# Search Artist: The Jam, Spotify Artist: King Von
# Search Artist: The Jam, Spotify Artist: The Cadillac Three
# Search Artist: The Jam, Spotify Artist: James Arthur
# Search Artist: The Jam, Spotify Artist: Kideko
# Search Artist: The Jam, Spotify Artist: James Arthur
# Search Artist: The Jam, Spotify Artist: Graham Central Station
# Search Artist: The Jam, Spotify Artist: Steven Universe
# Search Artist: The Jam, Spotify Artist: Jay Rock
# Search Artist: Bad Religion, Spotify Artist: Frank Ocean
# Search Artist: X, Spotify Artist: Lil Uzi Vert
# Search Artist: X, Spotify Artist: Lil Nas X
# Search Artist: X, Spotify Artist: 21 Savage
# Search Artist: X, Spotify Artist: Lil Nas X
# Search Artist: X, Spotify Artist: Kendrick Lamar
# Search Artist: X, Spotify Artist: Nicky Jam
# Search Artist: X, Spotify Artist: Billie Eilish
# Search Artist: X, Spotify Artist: XXXTENTACION
# Search Artist: X, Spotify Artist: DMX
# Search Artist: Blondie, Spotify Artist: Current Joys
# Search Artist: Elvis Costello, Spotify Artist: Elvis Costello & The Attractions
# Search Artist: Television, Spotify Artist: Rex Orange County
# Search Artist: Television, Spotify Artist: Wilmah
# Search Artist: Television, Spotify Artist: Current Joys
# Search Artist: Television, Spotify Artist: Sam Kim
# Search Artist: Television, Spotify Artist: The Reunion Show
# Search Artist: Television, Spotify Artist: Pale Waves
# Search Artist: Television, Spotify Artist: V
# Search Artist: Television, Spotify Artist: IDLES
# Search Artist: Television, Spotify Artist: Daft Punk
# Search Artist: Black Flag, Spotify Artist: HELLYEAH
# Search Artist: Black Flag, Spotify Artist: Various Artists
# Search Artist: Black Flag, Spotify Artist: Dirty
# Search Artist: Muddy Waters, Spotify Artist: LP
# Search Artist: B.B. King, Spotify Artist: Lil Wayne
# Search Artist: B.B. King, Spotify Artist: Sean Kingston
# Search Artist: Howlin’ Wolf, Spotify Artist: Howlin' Wolf
# Search Artist: Howlin’ Wolf, Spotify Artist: Howlin' Wolf
# Search Artist: Howlin’ Wolf, Spotify Artist: Howlin' Wolf
# Search Artist: Howlin’ Wolf, Spotify Artist: Howlin' Wolf
# Search Artist: Howlin’ Wolf, Spotify Artist: Howlin' Wolf
# Search Artist: Howlin’ Wolf, Spotify Artist: Howlin' Wolf
# Search Artist: Howlin’ Wolf, Spotify Artist: Howlin' Wolf
# Search Artist: Howlin’ Wolf, Spotify Artist: Guy Daniels
# Search Artist: Howlin’ Wolf, Spotify Artist: Howlin' Wolf
# Search Artist: Bessie Smith, Spotify Artist: Bob Dylan
# Search Artist: Muddy Waters, Spotify Artist: LP
# Search Artist: Gary Clark, Jr, Spotify Artist: John Legend
# Search Artist: Leadbelly, Spotify Artist: Various Artists
# Search Artist: Ray Charles, Spotify Artist: Third World Don
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Eric Clapton
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Howlin' Wolf
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Eric Clapton
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Eric Clapton
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Eric Clapton
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Eric Clapton
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Howlin' Wolf
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Howlin' Wolf
# Search Artist: Eric Clapton/Steve Winwood, Spotify Artist: Howlin' Wolf
# Search Artist: B.B. King, Spotify Artist: Lil Wayne
# Search Artist: B.B. King, Spotify Artist: Sean Kingston
# Search Artist: Bobby “Blue” Bland, Spotify Artist: Bobby "Blue" Bland
# Search Artist: Bobby “Blue” Bland, Spotify Artist: Lil Wayne
# Search Artist: Bobby “Blue” Bland, Spotify Artist: Bobby "Blue" Bland
# Search Artist: Bobby “Blue” Bland, Spotify Artist: Storyville
# Search Artist: Bobby “Blue” Bland, Spotify Artist: Bobby "Blue" Bland
# Search Artist: Bobby “Blue” Bland, Spotify Artist: Bobby "Blue" Bland
# Search Artist: Bobby “Blue” Bland, Spotify Artist: Tab Benoit
# Search Artist: Bobby “Blue” Bland, Spotify Artist:
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: David Allan Coe
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: David Allan Coe
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: The Highwaymen
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: The Highwaymen
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: Waylon Jennings
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: Waylon Jennings
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: The Highwaymen
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: The Highwaymen
# Search Artist: Waylon Jennings & Willie Nelson, Spotify Artist: Waylon Jennings
# Search Artist: Alabama, Spotify Artist: Cross Canadian Ragweed
# Search Artist: Alabama, Spotify Artist: Lynyrd Skynyrd
# Search Artist: Alabama, Spotify Artist: Bishop Gunn
# Search Artist: Alabama, Spotify Artist: Lynyrd Skynyrd
# Search Artist: Alabama, Spotify Artist: Mando Audio
# Search Artist: Reba Mcentire, Spotify Artist: Thomas Rhett
# Search Artist: Tim McGraw, Spotify Artist: Taylor Swift
# Search Artist: Mary Chapin Carpenter, Spotify Artist: Various Artists
# Search Artist: Jim Reeves, Spotify Artist: Martha Reeves & The Vandellas
# Search Artist: Rosanne Cash, Spotify Artist: Rodney Crowell
# Search Artist: Johnny Cash or Kris Kristofferson, Spotify Artist: The Highwaymen
# Search Artist: Johnny Cash or Kris Kristofferson, Spotify Artist: Johnny Cash
# Search Artist: Johnny Cash or Kris Kristofferson, Spotify Artist: The Highwaymen
# finished
# Ran in 55.480629205703735 seconds/0.9246771534283956 minutes
# There were 38 errors

# %%
results[3]
# Out:
# {'song': 'Like a Rolling Stone',
#  'artist': 'Bob Dylan',
#  'genius_artist': 'Bob Dylan',
#  'spotify_artist': 'Bob Dylan',
#  'artist_id': '74ASZWbe4lXaubB36ztrGX',
#  'album': '',
#  'artist_genre(s)': [],
#  'lyrics': 'Once upon a time you dressed so fine\nThrew the bums a dime in your prime, didn\'t you?\nPeople call, say "Beware doll, you\'re bound to fall"\nYou thought they were all a-kiddin\' you\nYou used to laugh about\nEverybody that was hangin\' out\nNow you don\'t talk so loud\nNow you don\'t seem so proud\nAbout having to be scrounging your next meal\n\nHow does it feel?\nHow does it feel?\nTo be without a home?\nLike a complete unknown?\nLike a rolling stone?\n\nAw, you\'ve gone to the finest school all right, Miss Lonely\nBut ya know ya only used to get juiced in it\nNobody\'s ever taught ya how to live out on the street\nAnd now you’re gonna have to get used to it\nYou say you never compromise\nWith the mystery tramp, but now you realize\nHe\'s not selling any alibis\nAs you stare into the vacuum of his eyes\nAnd say, “Do you want to make a deal?"\nHow does it feel?\nHow does it feel?\nTo be on your own\nWith no direction home\nA complete unknown\nLike a rolling stone?\n\nAw, you never turned around to see the frowns\nOn the jugglers and the clowns when they all did tricks for you\nNever understood that it ain\'t no good\nYou shouldn\'t let other people get your kicks for you\nYou used to ride on a chrome horse with your diplomat\nWho carried on his shoulder a Siamese cat\nAin\'t it hard when you discover that\nHe really wasn\'t where it\'s at\nAfter he took from you everything he could steal?\n\nHow does it feel?\nHow does it feel?\nTo hang on your own\nWith no direction home\nLike a complete unknown\nLike a rolling stone?\nAw, princess on the steeple and all the pretty people\nThey\'re all drinkin\', thinkin\' that they got it made\nExchangin\' all precious gifts\nBut you\'d better take your diamond ring, ya better pawn it, babe\nYou used to be so amused\nAt Napoleon in rags and the language that he used\nGo to him now, he calls ya, ya can\'t refuse\nWhen ya ain\'t got nothin\', you got nothin\' to lose\nYou\'re invisible now, ya got no secrets to conceal\nHow does it feel?\nAw, how does it feel?\nTo be on your own\nWith no direction home\nLike a complete unknown\nLike a rolling stone?61EmbedShare URLCopyEmbedCopy',
#  'audio_features': {}}

# %% [markdown]
# ### API Step 3: Search by Artist ID to Retrieve Genres and Audo Features
#
# Note: Spotify API cannot search using artist

# %%
# Initialize Spotify API v.2
AUTH_URL = 'https://accounts.spotify.com/api/token'

auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': spotify_id,
    'client_secret': spotify_secret,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
BASE_URL = 'https://api.spotify.com/v1/'

# %%
# Iterate through results, search by artist ID
# Get genres, add to list
# If results song is in album, get album and audio features

start = time.time()

spotify_errors = []

for item in results:
    
    try:
#         print(item["artist"]) # uncomment when troubleshooting
        artist_id = item["artist_id"]
        artist_genres = []
        r = requests.get(BASE_URL + 'artists/' + artist_id + '/albums', 
                     headers=headers, 
                     params={'include_groups': 'album', 'limit': 50})
#         print(r) # uncomment when troubleshooting
        d = r.json()
        albums = d["items"]

        for x in range(len(albums)):
            album_name = albums[x]["name"]

            # Get genres associated with artist - not always consistent w/ album, so iterate though all albums
            artist = sp.artist(albums[x]["artists"][0]["external_urls"]["spotify"])
            genres = artist["genres"]
            for genre in genres:
                if genre not in artist_genres:
                    artist_genres.append(genre)
                    
#         print(item["artist"], artist_genres) # uncomment when troubleshooting
        item["artist_genre(s)"] = artist_genres
        
    except:
        spotify_errors.append(item["artist"])
    
    
print("finished")
duration = time.time() - start
print(f'Ran in {duration} seconds/{duration/60} minutes')
print(f'There were {len(spotify_errors)} errors')
# Out:
# finished
# Ran in 1160.000637769699 seconds/19.33334396282832 minutes
# There were 43 errors

# %% [markdown]
# ### EDA and Cleaning

# %%
df = pd.DataFrame(results)

# %%
df.head(10)
# Out:
#                    song              artist       genius_artist  \
# 0          Satisfaction  The Rolling Stones  The Rolling Stones
# 1               Respect     Aretha Franklin     Aretha Franklin
# 2    Stairway to Heaven        Led Zeppelin        Led Zeppelin
# 3  Like a Rolling Stone           Bob Dylan           Bob Dylan
# 4           Born to Run   Bruce Springsteen   Bruce Springsteen
# 5      Hotel California          The Eagles        Genius Lists
# 6         Light My Fire           The Doors           The Doors
# 7       Good Vibrations      The Beach Boys      The Beach Boys
# 8              Hey Jude         The Beatles         The Beatles
# 9               Imagine         John Lennon         John Lennon
#
#        spotify_artist               artist_id album  \
# 0  The Rolling Stones  22bE4uQ6baNwSHPVcDxLCe
# 1     Aretha Franklin  7nwUJBm0HE4ZxD3f5cy5ok
# 2        Led Zeppelin  36QJpDe2go2KgaRleHCDTp
# 3           Bob Dylan  74ASZWbe4lXaubB36ztrGX
# 4   Bruce Springsteen  3eqjTLE0HfPfh78zjh6TqT
# 5
# 6           The Doors  22WZ7M8sxp5THdruNY3gXt
# 7      The Beach Boys  3oDbviiivRWhXwIE8hxkVV
# 8         The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 9         John Lennon  4x1nvY2FN8jxqAFA0DA02H
#
#                                      artist_genre(s)  \
# 0  [british invasion, classic rock, rock, blues, ...
# 1  [classic soul, jazz blues, memphis soul, soul,...
# 2        [album rock, classic rock, hard rock, rock]
# 3  [album rock, classic rock, country rock, folk,...
# 4  [classic rock, heartland rock, mellow gold, pe...
# 5                                                 []
# 6  [acid rock, classic rock, psychedelic rock, rock]
# 7  [baroque pop, brill building pop, classic rock...
# 8  [beatlesque, british invasion, classic rock, m...
# 9  [album rock, art rock, beatlesque, classic roc...
#
#                                               lyrics audio_features
# 0  I can't get no satisfaction\nI can't get no sa...             {}
# 1  What you want, baby, I got it\nWhat you need, ...             {}
# 2  There's a lady who's sure all that glitters is...             {}
# 3  Once upon a time you dressed so fine\nThrew th...             {}
# 4  In the day, we sweat it out on the streets\nOf...             {}
# 5  In alphabetical order by title:\nCan't find yo...             {}
# 6  You know that it would be untrue\nYou know tha...             {}
# 7  I-I love the colorful clothes she wears\nAnd t...             {}
# 8  Hey Jude, don't make it bad\nTake a sad song a...             {}
# 9  Imagine there's no heaven\nIt's easy if you tr...             {}

# %% [markdown]
# #### Analyze Genres

# %%
# Get list of lists of genres
genres_lol = df["artist_genre(s)"].to_list()

# %%
genres_lol
# Out:
# [['british invasion',
#   'classic rock',
#   'rock',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['classic soul', 'jazz blues', 'memphis soul', 'soul', 'southern soul'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter'],
#  ['classic rock',
#   'heartland rock',
#   'mellow gold',
#   'permanent wave',
#   'rock',
#   'singer-songwriter'],
#  [],
#  ['acid rock', 'classic rock', 'psychedelic rock', 'rock'],
#  ['baroque pop',
#   'brill building pop',
#   'classic rock',
#   'psychedelic rock',
#   'rock',
#   'sunshine pop'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'beatlesque',
#   'classic rock',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'soft rock'],
#  ['classic garage rock'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'british invasion',
#   'classic rock',
#   'folk rock',
#   'hard rock',
#   'mellow gold',
#   'rock'],
#  ['classic soul',
#   'funk',
#   'motown',
#   'northern soul',
#   'quiet storm',
#   'soul',
#   'adult standards',
#   'disco',
#   'mellow gold',
#   'soft rock'],
#  ['blues rock',
#   'classic rock',
#   'rock',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'blues',
#   'chicago blues',
#   'electric blues',
#   'funk',
#   'rhythm and blues',
#   'traditional blues'],
#  ['album rock',
#   'art rock',
#   'blues',
#   'blues rock',
#   'british blues',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock'],
#  ['album rock',
#   'art rock',
#   'british invasion',
#   'classic rock',
#   'folk rock',
#   'hard rock',
#   'mellow gold',
#   'rock'],
#  ['rock-and-roll', 'rockabilly'],
#  ['adult standards',
#   'classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'singer-songwriter',
#   'soft rock'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['motown', 'soul'],
#  ['funk',
#   'indie r&b',
#   'motown',
#   'quiet storm',
#   'soul',
#   'adult standards',
#   'brill building pop',
#   'disco',
#   'lounge',
#   'mellow gold',
#   'soft rock'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['british invasion',
#   'classic rock',
#   'rock',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['acid rock',
#   'album rock',
#   'blues rock',
#   'classic rock',
#   'psychedelic rock',
#   'rock'],
#  ['british invasion',
#   'classic rock',
#   'rock',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['classic rock', 'glam rock', 'rock'],
#  ['album rock',
#   'art rock',
#   'british invasion',
#   'classic rock',
#   'folk rock',
#   'glam rock',
#   'mellow gold',
#   'protopunk',
#   'psychedelic rock',
#   'rock'],
#  ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'folk rock',
#   'mellow gold',
#   'rock-and-roll',
#   'rockabilly',
#   'soft rock'],
#  ['classic rock', 'folk', 'folk rock', 'melancholia', 'mellow gold', 'rock'],
#  ['rock-and-roll', 'rockabilly'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['classic soul', 'memphis soul', 'soul', 'soul blues', 'southern soul'],
#  ['acid rock',
#   'album rock',
#   'blues rock',
#   'classic rock',
#   'psychedelic rock',
#   'rock'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['classic soul',
#   'funk',
#   'memphis soul',
#   'motown',
#   'soul',
#   'brill building pop',
#   'quiet storm',
#   'rock-and-roll',
#   'southern soul',
#   'classic girl group'],
#  ['adult standards', 'brill building pop', 'rock-and-roll', 'rockabilly'],
#  ['classic soul',
#   'funk',
#   'motown',
#   'northern soul',
#   'quiet storm',
#   'soul',
#   'adult standards',
#   'disco',
#   'mellow gold',
#   'soft rock'],
#  ['classic rock', 'country rock', 'rock', 'southern rock', 'swamp rock'],
#  ['acid rock',
#   'album rock',
#   'blues rock',
#   'classic canadian rock',
#   'classic rock',
#   'country rock',
#   'folk rock',
#   'hard rock',
#   'mellow gold',
#   'psychedelic rock',
#   'rock'],
#  ['grunge', 'permanent wave', 'rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'new wave',
#   'permanent wave',
#   'rock',
#   'soft rock'],
#  ['adult standards',
#   'classic soul',
#   'jazz blues',
#   'piano blues',
#   'soul',
#   'soul blues',
#   'vocal jazz'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'hard rock',
#   'mellow gold',
#   'rock',
#   'southern rock'],
#  ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'folk rock',
#   'rock-and-roll',
#   'rockabilly'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['brill building pop',
#   'bubblegum pop',
#   'classic rock',
#   'folk rock',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'sunshine pop'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['brill building pop',
#   'british invasion',
#   'bubblegum pop',
#   'classic garage rock',
#   'classic rock',
#   'folk rock',
#   'freakbeat',
#   'merseybeat',
#   'psychedelic rock',
#   'rock-and-roll'],
#  ['album rock',
#   'art rock',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'folk',
#   'folk rock',
#   'heartland rock',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock'],
#  ['pop', 'r&b', 'soul'],
#  ['adult standards',
#   'brill building pop',
#   'piano rock',
#   'rock-and-roll',
#   'rockabilly'],
#  ['disco', 'mellow gold', 'soft rock'],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['classic rock',
#   'folk rock',
#   'mellow gold',
#   'piano rock',
#   'rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['art rock', 'classic rock', 'glam rock', 'permanent wave', 'rock'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['adult standards', 'nashville sound', 'rockabilly'],
#  ['classic rock', 'permanent wave', 'punk', 'rock'],
#  ['british invasion',
#   'classic rock',
#   'rock',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['classic soul',
#   'funk',
#   'memphis soul',
#   'quiet storm',
#   'soul',
#   'soul blues',
#   'southern soul'],
#  ['rock-and-roll', 'rockabilly'],
#  ['adult standards', 'classic rock', 'mellow gold', 'soft rock'],
#  ['glam rock', 'mellow gold', 'piano rock'],
#  ['rock-and-roll', 'rockabilly'],
#  ['baroque pop',
#   'brill building pop',
#   'classic rock',
#   'psychedelic rock',
#   'rock',
#   'sunshine pop'],
#  ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'rock-and-roll',
#   'rockabilly'],
#  ['adult standards',
#   'brill building pop',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'japanese jazz'],
#  ['album rock',
#   'art rock',
#   'blues rock',
#   'classic rock',
#   'folk rock',
#   'hard rock',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'supergroup'],
#  ['baroque pop',
#   'brill building pop',
#   'classic rock',
#   'psychedelic rock',
#   'rock',
#   'sunshine pop'],
#  ['adult standards', 'brill building pop', 'rock-and-roll', 'rockabilly'],
#  ['rock-and-roll', 'rockabilly'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['adult standards',
#   'classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'singer-songwriter',
#   'soft rock',
#   'brill building pop'],
#  [],
#  ['classic soul',
#   'funk',
#   'motown',
#   'northern soul',
#   'quiet storm',
#   'soul',
#   'adult standards',
#   'disco',
#   'mellow gold',
#   'soft rock'],
#  ['british invasion',
#   'classic rock',
#   'rock',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'hard rock',
#   'mellow gold',
#   'rock',
#   'soft rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'new wave',
#   'permanent wave',
#   'rock',
#   'soft rock'],
#  ['classic rock', 'glam rock', 'rock'],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter'],
#  ['acid rock', 'classic rock', 'folk rock', 'psychedelic rock', 'rock'],
#  ['adult standards',
#   'brill building pop',
#   'motown',
#   'quiet storm',
#   'rock-and-roll',
#   'soul',
#   'southern soul',
#   'disco',
#   'funk',
#   'jazz funk',
#   'post-disco'],
#  ['adult standards',
#   'brill building pop',
#   'piano rock',
#   'rock-and-roll',
#   'rockabilly'],
#  ['australian rock', 'hard rock', 'rock'],
#  [],
#  ['brill building pop',
#   'classic soul',
#   'funk',
#   'memphis soul',
#   'motown',
#   'rock-and-roll',
#   'soul',
#   'southern soul'],
#  ['blues rock',
#   'british blues',
#   'british invasion',
#   'bubblegum pop',
#   'classic rock',
#   'folk rock',
#   'merseybeat',
#   'protopunk',
#   'psychedelic rock',
#   'rock',
#   'rock-and-roll'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock'],
#  ['classic rock',
#   'heartland rock',
#   'mellow gold',
#   'permanent wave',
#   'rock',
#   'singer-songwriter'],
#  ['reggae', 'roots reggae'],
#  ['adult standards', 'brill building pop', 'rock-and-roll', 'rockabilly'],
#  ['adult standards', 'mellow gold', 'soft rock'],
#  ['classic soul',
#   'funk',
#   'memphis soul',
#   'motown',
#   'soul',
#   'brill building pop',
#   'quiet storm',
#   'rock-and-roll',
#   'southern soul',
#   'classic girl group'],
#  ['classic rock',
#   'early us punk',
#   'permanent wave',
#   'punk',
#   'rock',
#   'skate punk'],
#  ['punk', 'rock'],
#  ['punk', 'rock'],
#  ['classic rock', 'permanent wave', 'punk', 'rock'],
#  ['early us punk', 'hardcore punk', 'punk', 'skate punk'],
#  ['california hardcore', 'hardcore punk', 'punk', 'ska punk'],
#  ['early us punk', 'pub rock', 'punk', "punk 'n' roll", 'punk blues'],
#  ['alternative rock',
#   'classic rock',
#   'detroit rock',
#   'garage rock',
#   'permanent wave',
#   'post-punk',
#   'protopunk',
#   'punk',
#   'punk blues',
#   'rock'],
#  ['classic rock',
#   'early us punk',
#   'permanent wave',
#   'punk',
#   'rock',
#   'skate punk'],
#  ['early us punk', 'hardcore punk', 'punk', 'skate punk'],
#  ['art punk',
#   'art rock',
#   'folk rock',
#   'permanent wave',
#   'protopunk',
#   'rock',
#   'experimental poetry'],
#  ['blues rock',
#   'classic garage rock',
#   'detroit rock',
#   'garage rock',
#   'protopunk',
#   'pub rock',
#   'punk',
#   'punk blues'],
#  ['alternative rock',
#   'hardcore punk',
#   'madchester',
#   'new wave',
#   'post-punk',
#   'pub rock',
#   'punk'],
#  ['classic rock', 'permanent wave', 'punk', 'rock'],
#  ['early us punk',
#   'glam punk',
#   'glam rock',
#   'post-punk',
#   'power pop',
#   'protopunk',
#   'pub rock',
#   'punk',
#   'punk blues'],
#  [],
#  ['art punk',
#   'art rock',
#   'dance rock',
#   'funk rock',
#   'new wave',
#   'permanent wave',
#   'post-punk',
#   'rock',
#   'zolo'],
#  [],
#  ['classic rock',
#   'early us punk',
#   'permanent wave',
#   'punk',
#   'rock',
#   'skate punk'],
#  ['alternative rock',
#   'gothic rock',
#   'hardcore punk',
#   'new wave',
#   'post-punk',
#   'pub rock',
#   'punk'],
#  ['permanent wave', 'punk'],
#  ['classic rock', 'permanent wave', 'punk', 'rock'],
#  ['alternative rock',
#   'classic rock',
#   'detroit rock',
#   'garage rock',
#   'permanent wave',
#   'post-punk',
#   'protopunk',
#   'punk',
#   'punk blues',
#   'rock'],
#  ['alternative rock',
#   'dc hardcore',
#   'noise rock',
#   'post-hardcore',
#   'post-punk',
#   'punk',
#   'rock'],
#  ['permanent wave', 'punk'],
#  ['alternative rock',
#   'black punk',
#   'dc hardcore',
#   'hardcore punk',
#   'nyhc',
#   'punk',
#   'ska punk'],
#  ['alternative metal',
#   'california hardcore',
#   'crossover thrash',
#   'funk metal',
#   'hardcore punk',
#   'metal',
#   'nu metal',
#   'old school thrash',
#   'punk',
#   'rap rock',
#   'rock',
#   'thrash metal'],
#  [],
#  [],
#  ['black punk', 'post-punk', 'pub rock', 'punk', 'riot grrrl'],
#  [],
#  ['hardcore punk', 'northern irish punk', 'oi', 'pub rock', 'punk', 'ska'],
#  ['alternative rock',
#   'hardcore punk',
#   'madchester',
#   'new wave',
#   'post-punk',
#   'pub rock',
#   'punk'],
#  ['punk', 'skate punk', 'socal pop punk'],
#  ['alternative rock',
#   'black punk',
#   'dc hardcore',
#   'hardcore punk',
#   'nyhc',
#   'punk',
#   'ska punk'],
#  ['permanent wave', 'punk'],
#  ['dc hardcore',
#   'hardcore punk',
#   'post-hardcore',
#   'punk',
#   'ska punk',
#   'skate punk',
#   'straight edge'],
#  ['classic rock', 'permanent wave', 'punk', 'rock'],
#  ['alternative pop',
#   'alternative rock',
#   'art rock',
#   'indie rock',
#   'new wave',
#   'permanent wave',
#   'pop rock',
#   'post-punk',
#   'power pop',
#   'punk',
#   'rock',
#   'roots rock'],
#  ['alternative pop',
#   'alternative rock',
#   'gbvfi',
#   'hardcore punk',
#   'new wave',
#   'post-hardcore',
#   'post-punk',
#   'power pop',
#   'punk'],
#  ['punk', 'ska', 'ska punk', 'skate punk'],
#  [],
#  ['alternative rock',
#   'black punk',
#   'dc hardcore',
#   'hardcore punk',
#   'nyhc',
#   'punk',
#   'ska punk'],
#  ['candy pop',
#   'new wave',
#   'new wave pop',
#   'permanent wave',
#   'power pop',
#   'rock'],
#  ['alternative rock',
#   'anti-folk',
#   'art rock',
#   'boston rock',
#   'new wave',
#   'psychedelic rock',
#   'punk',
#   'punk blues',
#   'folk',
#   'folk rock',
#   'freak folk',
#   'lo-fi',
#   'protopunk',
#   'singer-songwriter'],
#  ['permanent wave', 'punk'],
#  ['art rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'new wave pop',
#   'permanent wave',
#   'power pop',
#   'pub rock',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'choral',
#   'classical mezzo-soprano',
#   'classical performance',
#   'opera',
#   'classical saxophone'],
#  ['early us punk', 'hardcore punk', 'punk', 'skate punk'],
#  [],
#  ['california hardcore', 'hardcore punk', 'punk', 'ska punk'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'classic rock',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'jazz blues',
#   'soul blues',
#   'traditional blues',
#   'album rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'adult standards',
#   'vocal jazz',
#   'classic soul',
#   'soul',
#   'southern soul'],
#  ['acoustic blues',
#   'blues',
#   'blues rock',
#   'delta blues',
#   'pre-war blues',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'classic rock',
#   'country blues',
#   'electric blues',
#   'modern blues',
#   'soul blues',
#   'traditional blues',
#   'piano blues'],
#  ['adult standards',
#   'jazz blues',
#   'soul',
#   'soul blues',
#   'torch song',
#   'vocal jazz'],
#  ['acoustic blues',
#   'blues',
#   'blues rock',
#   'country blues',
#   'delta blues',
#   'texas blues',
#   'traditional blues',
#   'classic rock',
#   'electric blues',
#   'chicago blues',
#   'modern blues',
#   'soul blues'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'jazz blues',
#   'texas blues',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'delta blues',
#   'electric blues',
#   'memphis blues',
#   'modern blues',
#   'soul',
#   'traditional blues'],
#  ['acid rock',
#   'album rock',
#   'blues rock',
#   'classic rock',
#   'psychedelic rock',
#   'rock'],
#  [],
#  ['blues',
#   'harlem renaissance',
#   'jazz blues',
#   'traditional blues',
#   'big band',
#   'dixieland',
#   'jazz trumpet',
#   'new orleans jazz',
#   'ragtime',
#   'stride',
#   'swing',
#   'vintage jazz'],
#  ['album rock',
#   'art rock',
#   'blues',
#   'blues rock',
#   'british blues',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock'],
#  ['album rock',
#   'blues rock',
#   'british blues',
#   'classic rock',
#   'electric blues',
#   'hard rock',
#   'rock'],
#  ['brill building pop',
#   'classic soul',
#   'funk',
#   'memphis soul',
#   'motown',
#   'rock-and-roll',
#   'soul',
#   'southern soul'],
#  ['acoustic blues',
#   'blues',
#   'electric blues',
#   'harmonica blues',
#   'rhythm and blues',
#   'texas blues',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'memphis soul',
#   'soul blues',
#   'traditional blues',
#   'modern blues',
#   'roots rock',
#   'soul'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'delta blues',
#   'electric blues',
#   'rock-and-roll',
#   'traditional blues'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'country rock',
#   'swamp rock',
#   'blues',
#   'folk',
#   'folk rock',
#   'roots rock'],
#  ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'electric blues',
#   'jump blues',
#   'traditional blues',
#   'piano blues'],
#  ['adult standards',
#   'jazz blues',
#   'soul',
#   'soul blues',
#   'torch song',
#   'vocal jazz'],
#  ['british invasion',
#   'classic rock',
#   'rock',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'classic rock',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'electric blues',
#   'modern blues',
#   'modern blues rock',
#   'power blues-rock',
#   'texas blues'],
#  ['blues', 'louisiana blues', 'new orleans blues', 'traditional blues'],
#  ['album rock',
#   'blues',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'instrumental rock',
#   'modern blues',
#   'rock',
#   'texas blues',
#   'memphis soul',
#   'soul blues',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'classic rock',
#   'country blues',
#   'electric blues',
#   'modern blues',
#   'soul blues',
#   'traditional blues',
#   'piano blues'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'delta blues',
#   'electric blues',
#   'memphis blues',
#   'modern blues',
#   'soul',
#   'traditional blues'],
#  ['blues rock',
#   'electric blues',
#   'funk',
#   'modern alternative rock',
#   'modern blues',
#   'modern blues rock',
#   'rock',
#   'soul blues',
#   'texas blues'],
#  ['blues',
#   'blues rock',
#   'electric blues',
#   'modern blues',
#   'modern blues rock'],
#  ['blues',
#   'blues rock',
#   'british blues',
#   'classic rock',
#   'electric blues',
#   'modern blues'],
#  ['classic rock',
#   'country rock',
#   'electric blues',
#   'folk',
#   'folk rock',
#   'heartland rock',
#   'lilith',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock',
#   'cosmic american',
#   'psychedelic rock'],
#  ['acoustic blues',
#   'appalachian folk',
#   'blues',
#   'country blues',
#   'delta blues',
#   'folk',
#   'texas blues',
#   'traditional blues',
#   'traditional folk',
#   'american folk revival',
#   'protest folk',
#   'singer-songwriter'],
#  ['adult standards',
#   'classic soul',
#   'jazz blues',
#   'piano blues',
#   'soul',
#   'soul blues',
#   'vocal jazz'],
#  [],
#  ['album rock',
#   'blues',
#   'blues rock',
#   'british blues',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'hard rock',
#   'modern blues',
#   'rock'],
#  ['blues',
#   'blues rock',
#   'electric blues',
#   'modern blues',
#   'modern blues rock'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'jazz blues',
#   'soul blues',
#   'traditional blues',
#   'album rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'adult standards',
#   'vocal jazz',
#   'classic soul',
#   'soul',
#   'southern soul'],
#  [],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'classic rock',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'double drumming',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'hard rock',
#   'heartland rock',
#   'mellow gold',
#   'rock'],
#  [],
#  [],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'classic rock',
#   'country blues',
#   'electric blues',
#   'modern blues',
#   'soul blues',
#   'traditional blues',
#   'piano blues'],
#  ['blues', 'blues rock', 'country rock', 'electric blues', 'modern blues'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'jazz blues',
#   'soul blues',
#   'traditional blues',
#   'album rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'adult standards',
#   'vocal jazz',
#   'classic soul',
#   'soul',
#   'southern soul'],
#  ['acoustic blues',
#   'blues',
#   'blues rock',
#   'country blues',
#   'delta blues',
#   'texas blues',
#   'traditional blues',
#   'classic rock',
#   'electric blues',
#   'chicago blues',
#   'modern blues',
#   'soul blues'],
#  [],
#  ['album rock',
#   'classic rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'yacht rock',
#   'blues',
#   'chicago blues',
#   'piano blues'],
#  ['blues',
#   'chicago blues',
#   'electric blues',
#   'harmonica blues',
#   'memphis blues',
#   'traditional blues'],
#  ['blues', 'blues rock', 'electric blues', 'modern blues', 'texas blues'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'delta blues',
#   'electric blues',
#   'memphis blues',
#   'modern blues',
#   'soul',
#   'traditional blues'],
#  ['brill building pop', 'classic soul', 'motown', 'soul', 'southern soul'],
#  ['classic rock',
#   'country rock',
#   'electric blues',
#   'folk',
#   'folk rock',
#   'heartland rock',
#   'lilith',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock',
#   'cosmic american',
#   'psychedelic rock'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'country rock',
#   'swamp rock',
#   'blues',
#   'folk',
#   'folk rock',
#   'roots rock'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'modern blues',
#   'modern blues rock',
#   'rock'],
#  ['country blues', 'louisiana blues', 'new orleans blues'],
#  ['american modern classical',
#   'classical',
#   'early modern classical',
#   'tin pan alley',
#   'big band',
#   'harlem renaissance',
#   'jazz blues',
#   'swing'],
#  ['classic soul', 'funk', 'motown', 'soul', 'soul blues', 'southern soul'],
#  [],
#  ['adult standards',
#   'classic soul',
#   'jazz blues',
#   'piano blues',
#   'soul',
#   'soul blues',
#   'vocal jazz'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'double drumming',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['modern blues rock'],
#  ['acoustic blues',
#   'blues',
#   'boogie-woogie',
#   'chicago blues',
#   'traditional blues'],
#  ['motown', 'soul'],
#  ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'country blues',
#   'delta blues',
#   'harmonica blues',
#   'traditional blues',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'modern blues',
#   'soul blues'],
#  ['acoustic blues',
#   'blues',
#   'blues rock',
#   'classic rock',
#   'country blues',
#   'country rock',
#   'folk',
#   'folk rock',
#   'funk',
#   'harmonica blues',
#   'jazz blues',
#   'modern blues',
#   'roots rock',
#   'soul',
#   'traditional blues',
#   'gospel singers'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'modern blues',
#   'traditional blues',
#   'classic rock',
#   'memphis soul',
#   'soul blues'],
#  ['acoustic blues',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'traditional blues'],
#  ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'electric blues',
#   'jump blues',
#   'traditional blues',
#   'piano blues'],
#  [],
#  ['acoustic blues',
#   'blues',
#   'country blues',
#   'harmonica blues',
#   'piedmont blues',
#   'traditional blues',
#   'blues rock',
#   'delta blues',
#   'texas blues'],
#  [],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'hard rock',
#   'rock'],
#  ['blues rock',
#   'electric blues',
#   'modern blues',
#   'modern blues rock',
#   'power blues-rock'],
#  ['blues',
#   'electric blues',
#   'memphis soul',
#   'soul',
#   'soul blues',
#   'southern soul'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'country rock',
#   'swamp rock',
#   'blues',
#   'folk',
#   'folk rock',
#   'roots rock'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'classic rock',
#   'electric blues',
#   'funk',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'traditional blues'],
#  [],
#  ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'electric blues',
#   'jump blues',
#   'traditional blues',
#   'piano blues'],
#  [],
#  ['blues',
#   'boogie-woogie',
#   'electric blues',
#   'jump blues',
#   'soul blues',
#   'texas blues',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'harmonica blues',
#   'rock-and-roll',
#   'traditional blues'],
#  ['blues rock',
#   'classic rock',
#   'rock',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'blues',
#   'chicago blues',
#   'electric blues',
#   'funk',
#   'rhythm and blues',
#   'traditional blues'],
#  [],
#  ['blues', 'blues rock', 'chicago blues', 'electric blues', 'modern blues'],
#  ['acoustic blues',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'modern blues',
#   'traditional blues'],
#  ['acoustic blues',
#   'blues',
#   'country blues',
#   'harmonica blues',
#   'piedmont blues',
#   'traditional blues',
#   'blues rock',
#   'delta blues',
#   'texas blues'],
#  ['british invasion',
#   'classic rock',
#   'rock',
#   'blues',
#   'blues rock',
#   'chicago blues',
#   'electric blues',
#   'soul',
#   'traditional blues'],
#  ['blues', 'blues rock', 'electric blues', 'modern blues', 'texas blues'],
#  ['blues',
#   'blues rock',
#   'classic rock',
#   'delta blues',
#   'electric blues',
#   'memphis blues',
#   'modern blues',
#   'soul',
#   'traditional blues'],
#  ['album rock',
#   'blues',
#   'blues rock',
#   'classic rock',
#   'electric blues',
#   'instrumental rock',
#   'modern blues',
#   'rock',
#   'texas blues',
#   'memphis soul',
#   'soul blues',
#   'traditional blues'],
#  ['blues',
#   'blues rock',
#   'electric blues',
#   'modern blues',
#   'soul blues',
#   'texas blues'],
#  ['conscious hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'political hip hop',
#   'rap'],
#  ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'],
#  ['east coast hip hop',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'queens hip hop',
#   'rap'],
#  ['bronx hip hop', 'electro', 'old school hip hop'],
#  [],
#  ['east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'rap',
#   'hip pop',
#   'neo soul',
#   'new jack swing',
#   'quiet storm',
#   'r&b',
#   'urban contemporary'],
#  ['g funk',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap',
#   'west coast trap',
#   'synth funk'],
#  ['dance pop',
#   'girl group',
#   'golden age hip hop',
#   'hip hop',
#   'hip pop',
#   'old school hip hop',
#   'pop rap',
#   'queens hip hop',
#   'rap'],
#  ['east coast hip hop',
#   'electro',
#   'harlem hip hop',
#   'hip hop',
#   'hip house',
#   'old school hip hop',
#   'rap'],
#  ['east coast hip hop', 'hip hop', 'pop rap', 'rap'],
#  ['east coast hip hop',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'hip pop',
#   'old school hip hop',
#   'pop rap',
#   'queens hip hop',
#   'rap',
#   'southern hip hop'],
#  ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap'],
#  ['g funk',
#   'gangster rap',
#   'hip hop',
#   'rap',
#   'west coast rap',
#   'alternative hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'hardcore hip hop',
#   'political hip hop'],
#  ['detroit hip hop', 'hip hop', 'rap'],
#  ['dance pop',
#   'hip hop',
#   'hip pop',
#   'pop',
#   'pop rap',
#   'r&b',
#   'rap',
#   'urban contemporary',
#   'virginia hip hop'],
#  ['gangster rap', 'hip hop', 'hip house', 'old school hip hop', 'rap'],
#  ['east coast hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'queens hip hop',
#   'rap'],
#  ['conscious hip hop',
#   'electro',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'new jersey rap',
#   'old school hip hop',
#   'rap',
#   'west coast rap',
#   'alternative metal',
#   'funk metal',
#   'nu metal',
#   'political hip hop',
#   'rap metal',
#   'rap rock'],
#  ['chicago rap', 'rap', 'hip hop', 'east coast hip hop', 'pop rap'],
#  [],
#  ['east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'hip pop',
#   'new jersey rap',
#   'pop rap',
#   'rap'],
#  ['atl hip hop', 'dirty south rap', 'hip hop', 'rap', 'southern hip hop'],
#  ['alternative hip hop',
#   'bboy',
#   'east coast hip hop',
#   'electro',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'rap',
#   'turntablism'],
#  ['east coast hip hop', 'gangster rap', 'hip hop', 'new jersey rap', 'rap'],
#  ['hip hop', 'hip house', 'new jack swing', 'rap'],
#  ['alternative rock',
#   'east coast hip hop',
#   'golden age hip hop',
#   'hip hop',
#   'old school hip hop',
#   'rap',
#   'rap rock'],
#  ['conscious hip hop',
#   'g funk',
#   'gangster rap',
#   'hip hop',
#   'rap',
#   'west coast rap'],
#  ['conscious hip hop',
#   'funk',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'hip house',
#   'rap',
#   'west coast rap'],
#  ['alternative hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'jazz rap',
#   'queens hip hop',
#   'rap'],
#  ['east coast hip hop',
#   'electro',
#   'gangster rap',
#   'harlem hip hop',
#   'hip hop',
#   'hip house',
#   'new jack swing',
#   'old school hip hop',
#   'rap'],
#  ['dance pop',
#   'east coast hip hop',
#   'hip hop',
#   'hip pop',
#   'pop rap',
#   'rap',
#   'israeli techno',
#   'microhouse',
#   'minimal tech house',
#   'minimal techno',
#   'organic electronic',
#   'organic house',
#   'tech house'],
#  ['gangster rap',
#   'hip hop',
#   'ohio hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'chicano rap'],
#  ['chicano rap',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'rap',
#   'rap rock',
#   'west coast rap'],
#  ['conscious hip hop',
#   'east coast hip hop',
#   'golden age hip hop',
#   'hip hop',
#   'hip pop',
#   'new jersey rap'],
#  ['dance pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'st louis rap',
#   'urban contemporary'],
#  [],
#  ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap'],
#  [],
#  ['east coast hip hop',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'queens hip hop',
#   'rap'],
#  [],
#  [],
#  [],
#  ['east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop'],
#  ['conscious hip hop',
#   'dirty south rap',
#   'g funk',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'rap',
#   'southern hip hop'],
#  ['alternative hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'jazz rap',
#   'rap'],
#  ['hip hop', 'rap'],
#  ['conscious hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'hip hop',
#   'queens hip hop',
#   'rap',
#   'reggae',
#   'reggae fusion'],
#  ['bronx hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'electro',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'rap',
#   'turntablism'],
#  ['hip hop',
#   'new orleans rap',
#   'pop rap',
#   'rap',
#   'trap',
#   'atl hip hop',
#   'southern hip hop'],
#  ['cali rap',
#   'hyphy',
#   'oakland hip hop',
#   'beatboxing',
#   'east coast hip hop',
#   'electro',
#   'harlem hip hop',
#   'old school hip hop'],
#  ['east coast hip hop', 'hip hop', 'hip pop', 'pop rap', 'r&b', 'rap'],
#  ['east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'hip pop',
#   'pop rap',
#   'rap'],
#  ['east coast hip hop',
#   'electro',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'hip house',
#   'hip pop',
#   'new jack swing',
#   'old school hip hop',
#   'rap'],
#  ['bronx hip hop', 'hardcore hip hop'],
#  ['east coast hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'hip pop',
#   'pop rap',
#   'rap'],
#  ['east coast hip hop',
#   'electro',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'rap'],
#  ['atl hip hop',
#   'dirty south rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  [],
#  ['east coast hip hop',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'hip pop',
#   'old school hip hop',
#   'pop rap',
#   'queens hip hop',
#   'rap',
#   'southern hip hop'],
#  ['alternative hip hop',
#   'bronx hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'rap'],
#  ['afrofuturism',
#   'alternative hip hop',
#   'east coast hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'jazz rap',
#   'psychedelic hip hop',
#   'rap'],
#  ['electro',
#   'golden age hip hop',
#   'hip hop',
#   'hip house',
#   'new jack swing',
#   'old school hip hop',
#   'rap'],
#  ['alternative hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'indie r&b',
#   'philly rap',
#   'political hip hop',
#   'southern hip hop',
#   'classic soul',
#   'funk',
#   'motown',
#   'quiet storm',
#   'soul',
#   'southern soul',
#   'neo soul',
#   'pop',
#   'pop soul',
#   'r&b',
#   'urban contemporary'],
#  ['electro', 'harlem hip hop', 'hip house', 'old school hip hop'],
#  ['gangster rap', 'hardcore hip hop', 'hip hop', 'rap', 'west coast rap'],
#  ['gangster rap',
#   'hardcore hip hop',
#   'harlem hip hop',
#   'hip hop',
#   'hip pop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'urban contemporary'],
#  ['atl hip hop',
#   'dance pop',
#   'dirty south rap',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['alternative hip hop',
#   'chicago rap',
#   'conscious hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'neo soul',
#   'political hip hop',
#   'rap'],
#  ['east coast hip hop',
#   'electro',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'hip house',
#   'rap'],
#  ['east coast hip hop',
#   'electro',
#   'funk',
#   'gangster rap',
#   'hip hop',
#   'hip house',
#   'miami bass',
#   'new jack swing',
#   'old school hip hop',
#   'quiet storm',
#   'rap'],
#  ['electro', 'miami bass', 'old school hip hop'],
#  [],
#  ['east coast hip hop',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'rap'],
#  ['dance pop',
#   'east coast hip hop',
#   'gangster rap',
#   'hip hop',
#   'hip pop',
#   'pop rap',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'trap queen',
#   'urban contemporary'],
#  ['bronx hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'hip pop',
#   'rap',
#   'southern hip hop'],
#  [],
#  ['atl hip hop', 'conscious hip hop', 'hip hop', 'rap'],
#  ['east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'dubstep product'],
#  ['crunk',
#   'dirty south rap',
#   'gangster rap',
#   'hip hop',
#   'memphis hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'tennessee hip hop',
#   'trap'],
#  [],
#  ['east coast hip hop',
#   'electro',
#   'hardcore hip hop',
#   'hip hop',
#   'hip house',
#   'old school hip hop',
#   'rap'],
#  ['electro',
#   'gangster rap',
#   'golden age hip hop',
#   'hip hop',
#   'hip house',
#   'miami bass',
#   'miami hip hop',
#   'old school hip hop',
#   'rap'],
#  ['electro', 'hip house', 'old school hip hop'],
#  ['alternative hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'political hip hop',
#   'southern hip hop'],
#  ['east coast hip hop',
#   'electro',
#   'funk',
#   'hardcore hip hop',
#   'hip hop',
#   'hip house',
#   'hip pop',
#   'new jack swing',
#   'old school hip hop',
#   'quiet storm',
#   'r&b',
#   'rap',
#   'urban contemporary'],
#  ['rap kreyol',
#   'east coast hip hop',
#   'gangster rap',
#   'hip hop',
#   'new jersey rap',
#   'rap'],
#  ['alternative hip hop',
#   'east coast hip hop',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'hip house',
#   'jazz rap',
#   'old school hip hop',
#   'rap',
#   'turntablism'],
#  ['battle rap',
#   'east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'harlem hip hop',
#   'hip hop',
#   'hip pop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['alternative hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'jazz rap',
#   'turntablism'],
#  ['dirty south rap',
#   'gangster rap',
#   'houston rap',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'chopped and screwed',
#   'crunk',
#   'hip hop'],
#  [],
#  [],
#  ['dirty south rap',
#   'gangster rap',
#   'hip hop',
#   'houston rap',
#   'new orleans rap',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['miami bass', 'miami hip hop', 'old school hip hop'],
#  ['gangster rap',
#   'golden age hip hop',
#   'hip hop',
#   'old school hip hop',
#   'philly rap',
#   'rap'],
#  [],
#  ['g funk',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap'],
#  ['atl hip hop',
#   'crunk',
#   'dirty south rap',
#   'gangster rap',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['east coast hip hop',
#   'electro',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'old school hip hop',
#   'rap'],
#  ['country',
#   'country dawn',
#   'country rock',
#   'nashville sound',
#   'honky tonk',
#   'classic country pop'],
#  ['country', 'country rock', 'honky tonk'],
#  ['adult standards', 'nashville sound', 'rockabilly'],
#  ['arkansas country', 'outlaw country'],
#  ['folk',
#   'honky tonk',
#   'rock-and-roll',
#   'rockabilly',
#   'traditional country',
#   'yodeling',
#   'country',
#   'country road',
#   'country rock',
#   'outlaw country'],
#  [],
#  ['adult standards', 'nashville sound', 'rockabilly'],
#  ['adult standards',
#   'arkansas country',
#   'brill building pop',
#   'bubblegum pop',
#   'classic country pop',
#   'folk rock',
#   'mellow gold',
#   'nashville sound',
#   'soft rock',
#   'canadian country',
#   'canadian pop',
#   'bluegrass gospel',
#   'country boogie',
#   'country gospel',
#   'yodeling'],
#  ['arkansas country',
#   'country',
#   'country rock',
#   'nashville sound',
#   'rockabilly'],
#  [],
#  ['appalachian folk',
#   'bluegrass',
#   'bluegrass gospel',
#   'country gospel',
#   'old-time',
#   'progressive bluegrass',
#   'traditional country',
#   'traditional folk'],
#  ['contemporary country', 'country', 'country road', 'country rock'],
#  ['country',
#   'country rock',
#   'nashville sound',
#   'arkansas country',
#   'adult standards',
#   'rockabilly',
#   'classic country pop',
#   'country dawn'],
#  [],
#  ['country', 'country gospel', 'country road', 'country rock'],
#  ['classic country pop',
#   'country',
#   'country dawn',
#   'country gospel',
#   'nashville sound',
#   'country rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'outlaw country',
#   'roots rock',
#   'singer-songwriter'],
#  ['arkansas country', 'country', 'country rock', 'nashville sound'],
#  ['classic country pop', 'folk', 'folk rock', 'mellow gold', 'soft rock'],
#  ['folk',
#   'honky tonk',
#   'rock-and-roll',
#   'rockabilly',
#   'traditional country',
#   'yodeling',
#   'country',
#   'country road',
#   'country rock',
#   'outlaw country'],
#  ['bakersfield sound',
#   'country',
#   'country rock',
#   'nashville sound',
#   'outlaw country',
#   'classic country pop',
#   'singer-songwriter',
#   'texas country',
#   'honky tonk'],
#  ['country', 'country dawn'],
#  ['classic country pop',
#   'country',
#   'country rock',
#   'nashville sound',
#   'outlaw country',
#   'singer-songwriter',
#   'texas country'],
#  ['contemporary country', 'country', 'country road', 'country rock'],
#  ['arkansas country', 'outlaw country'],
#  ['adult standards',
#   'classic country pop',
#   'country',
#   'mellow gold',
#   'nashville sound',
#   'soft rock',
#   'country dawn'],
#  ['contemporary country', 'country', 'country dawn', 'oklahoma country'],
#  ['contemporary country', 'country', 'country road', 'country rock'],
#  ['folk',
#   'honky tonk',
#   'rock-and-roll',
#   'rockabilly',
#   'traditional country',
#   'yodeling',
#   'country',
#   'country road',
#   'country rock',
#   'outlaw country'],
#  ['contemporary country', 'country', 'country dawn', 'country road'],
#  ['arkansas country', 'outlaw country'],
#  ['adult standards',
#   'arkansas country',
#   'brill building pop',
#   'bubblegum pop',
#   'classic country pop',
#   'folk rock',
#   'mellow gold',
#   'nashville sound',
#   'soft rock',
#   'canadian country',
#   'canadian pop',
#   'bluegrass gospel',
#   'country boogie',
#   'country gospel',
#   'yodeling'],
#  ['classic country pop',
#   'country',
#   'country rock',
#   'nashville sound',
#   'outlaw country',
#   'singer-songwriter',
#   'texas country'],
#  ['classic country pop'],
#  ['country',
#   'country dawn',
#   'country rock',
#   'nashville sound',
#   'honky tonk',
#   'classic country pop'],
#  ['country',
#   'country rock',
#   'folk',
#   'nashville sound',
#   'oklahoma country',
#   'classic country pop',
#   'outlaw country',
#   'singer-songwriter',
#   'texas country'],
#  ['contemporary country',
#   'country',
#   'country road',
#   'country dawn',
#   'dance pop'],
#  ['adult standards', 'nashville sound', 'traditional country', 'yodeling'],
#  ['classic country pop',
#   'honky tonk',
#   'rockabilly',
#   'traditional country',
#   'country',
#   'country dawn',
#   'country rock',
#   'nashville sound',
#   'arkansas country',
#   'outlaw country'],
#  ['adult standards', 'nashville sound', 'rockabilly'],
#  ['cowboy western', 'nashville sound'],
#  ['classic country pop',
#   'country',
#   'country dawn',
#   'country rock',
#   'outlaw country'],
#  ['country', 'country road', 'country rock', 'oklahoma country'],
#  ['bakersfield sound', 'country', 'country rock'],
#  [],
#  ['country',
#   'country rock',
#   'nashville sound',
#   'arkansas country',
#   'adult standards',
#   'rockabilly',
#   'classic country pop',
#   'country dawn'],
#  ['contemporary country', 'country', 'country road', 'country rock'],
#  ['adult standards',
#   'classic soul',
#   'jazz blues',
#   'piano blues',
#   'soul',
#   'soul blues',
#   'vocal jazz'],
#  ['contemporary country', 'country', 'country dawn', 'country road'],
#  ['nashville sound', 'traditional country'],
#  ['country', 'country gospel', 'country road', 'country rock'],
#  ['country rock',
#   'cowboy western',
#   'honky tonk',
#   'traditional country',
#   'western swing'],
#  ['classic country pop',
#   'country',
#   'country dawn',
#   'country gospel',
#   'nashville sound',
#   'country rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'outlaw country',
#   'roots rock',
#   'singer-songwriter'],
#  ['bakersfield sound', 'country', 'country rock', 'cowboy western'],
#  ['country', 'country dawn', 'country rock'],
#  ['classic country pop',
#   'country',
#   'country rock',
#   'nashville sound',
#   'outlaw country',
#   'singer-songwriter',
#   'texas country'],
#  ['classic country pop', 'country', 'country rock', 'nashville sound'],
#  ['country',
#   'country road',
#   'country rock',
#   'outlaw country',
#   'folk',
#   'honky tonk',
#   'rock-and-roll',
#   'rockabilly',
#   'traditional country',
#   'yodeling',
#   'adult standards',
#   'brill building pop',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  ['country', 'country road', 'country rock', 'oklahoma country'],
#  ['folk',
#   'honky tonk',
#   'rock-and-roll',
#   'rockabilly',
#   'traditional country',
#   'yodeling',
#   'country',
#   'country road',
#   'country rock',
#   'outlaw country'],
#  ['contemporary country', 'country', 'country road', 'country rock'],
#  ['adult standards',
#   'brill building pop',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  ['bluegrass', 'progressive bluegrass'],
#  ['country',
#   'country rock',
#   'celtic',
#   'celtic rock',
#   'irish folk',
#   'operatic pop'],
#  ['country gospel', 'nashville sound', 'brill building pop'],
#  [],
#  ['classic country pop', 'honky tonk', 'rockabilly'],
#  ['classic rock', 'country', 'country rock', 'southern rock'],
#  ['bakersfield sound', 'country', 'country rock'],
#  ['country', 'country dawn', 'country rock', 'kentucky roots'],
#  ['arkansas country', 'outlaw country'],
#  ['country gospel', 'traditional country'],
#  ['country', 'country rock'],
#  ['contemporary country', 'country', 'country dawn'],
#  [],
#  ['canadian country', 'canadian pop', 'country', 'country dawn', 'dance pop'],
#  ['country', 'country road', 'country rock'],
#  ['contemporary country', 'country', 'country dawn', 'oklahoma country'],
#  ['contemporary country',
#   'country',
#   'country dawn',
#   'country road',
#   'country rock'],
#  ['classic country pop', 'country', 'country rock', 'nashville sound'],
#  ['contemporary country', 'country', 'country road', 'oklahoma country'],
#  ['classic country pop', 'nashville sound'],
#  ['contemporary country', 'country', 'country road'],
#  ['country', 'country dawn', 'dance pop'],
#  ['new mexico music', 'swamp pop'],
#  ['country', 'country rock', 'folk', 'folk rock', 'lilith', 'mellow gold'],
#  ['adult standards',
#   'cowboy western',
#   'oklahoma country',
#   'traditional country',
#   'yodeling'],
#  ['contemporary country',
#   'country',
#   'country road',
#   'country rock',
#   'outlaw country'],
#  ['adult standards', 'nashville sound'],
#  ['country',
#   'country rock',
#   'folk',
#   'folk rock',
#   'lilith',
#   'mellow gold',
#   'roots rock',
#   'singer-songwriter'],
#  [],
#  ['country', 'country rock', 'outlaw country', 'honky tonk'],
#  ['country', 'country dawn', 'country rock'],
#  ['country', 'country road', 'country rock'],
#  ['contemporary country', 'country', 'country road'],
#  [],
#  ['adult standards',
#   'cowboy western',
#   'oklahoma country',
#   'traditional country',
#   'yodeling'],
#  ['country', 'country road', 'country rock']]

# %%
# Initialize genre list
genres = []

# Remove genres from individual lists and add to master genre list
for genre_list in genres_lol:
    for i in genre_list:
        genres.append(i)
print(f'There are {len(genres)} non-unique genres')
# Out:
# There are 2667 non-unique genres

# %%
# Get list of unique Genres

# Initialize genre list
unique_genres = []

for item in genres:
    if item not in unique_genres:
        unique_genres.append(item)
print(f'There are {len(unique_genres)} unique genres')
# Out:
# There are 267 unique genres

# %%
unique_genres.sort()
unique_genres
# Out:
# ['acid rock',
#  'acoustic blues',
#  'adult standards',
#  'afrofuturism',
#  'album rock',
#  'alternative hip hop',
#  'alternative metal',
#  'alternative pop',
#  'alternative rock',
#  'american folk revival',
#  'american modern classical',
#  'anti-folk',
#  'appalachian folk',
#  'arkansas country',
#  'art punk',
#  'art rock',
#  'atl hip hop',
#  'australian rock',
#  'bakersfield sound',
#  'baroque pop',
#  'battle rap',
#  'bboy',
#  'beatboxing',
#  'beatlesque',
#  'big band',
#  'black punk',
#  'bluegrass',
#  'bluegrass gospel',
#  'blues',
#  'blues rock',
#  'boogie-woogie',
#  'boston rock',
#  'brill building pop',
#  'british blues',
#  'british invasion',
#  'bronx hip hop',
#  'bubblegum pop',
#  'cali rap',
#  'california hardcore',
#  'canadian country',
#  'canadian pop',
#  'candy pop',
#  'celtic',
#  'celtic rock',
#  'chicago blues',
#  'chicago rap',
#  'chicano rap',
#  'chopped and screwed',
#  'choral',
#  'classic canadian rock',
#  'classic country pop',
#  'classic garage rock',
#  'classic girl group',
#  'classic rock',
#  'classic soul',
#  'classical',
#  'classical mezzo-soprano',
#  'classical performance',
#  'classical saxophone',
#  'conscious hip hop',
#  'contemporary country',
#  'cosmic american',
#  'country',
#  'country blues',
#  'country boogie',
#  'country dawn',
#  'country gospel',
#  'country road',
#  'country rock',
#  'cowboy western',
#  'crossover thrash',
#  'crunk',
#  'dance pop',
#  'dance rock',
#  'dc hardcore',
#  'delta blues',
#  'detroit hip hop',
#  'detroit rock',
#  'dirty south rap',
#  'disco',
#  'dixieland',
#  'double drumming',
#  'dubstep product',
#  'early modern classical',
#  'early us punk',
#  'east coast hip hop',
#  'easy listening',
#  'electric blues',
#  'electro',
#  'experimental poetry',
#  'folk',
#  'folk rock',
#  'freak folk',
#  'freakbeat',
#  'funk',
#  'funk metal',
#  'funk rock',
#  'g funk',
#  'gangster rap',
#  'garage rock',
#  'gbvfi',
#  'girl group',
#  'glam punk',
#  'glam rock',
#  'golden age hip hop',
#  'gospel singers',
#  'gothic rock',
#  'grunge',
#  'hard rock',
#  'hardcore hip hop',
#  'hardcore punk',
#  'harlem hip hop',
#  'harlem renaissance',
#  'harmonica blues',
#  'heartland rock',
#  'hip hop',
#  'hip house',
#  'hip pop',
#  'honky tonk',
#  'houston rap',
#  'hyphy',
#  'indie r&b',
#  'indie rock',
#  'instrumental rock',
#  'irish folk',
#  'israeli techno',
#  'jam band',
#  'japanese jazz',
#  'jazz blues',
#  'jazz funk',
#  'jazz rap',
#  'jazz trumpet',
#  'jump blues',
#  'kentucky roots',
#  'lilith',
#  'lo-fi',
#  'louisiana blues',
#  'lounge',
#  'madchester',
#  'melancholia',
#  'mellow gold',
#  'memphis blues',
#  'memphis hip hop',
#  'memphis soul',
#  'merseybeat',
#  'metal',
#  'miami bass',
#  'miami hip hop',
#  'microhouse',
#  'minimal tech house',
#  'minimal techno',
#  'modern alternative rock',
#  'modern blues',
#  'modern blues rock',
#  'motown',
#  'nashville sound',
#  'neo soul',
#  'new jack swing',
#  'new jersey rap',
#  'new mexico music',
#  'new orleans blues',
#  'new orleans jazz',
#  'new orleans rap',
#  'new wave',
#  'new wave pop',
#  'noise rock',
#  'northern irish punk',
#  'northern soul',
#  'nu metal',
#  'nyhc',
#  'oakland hip hop',
#  'ohio hip hop',
#  'oi',
#  'oklahoma country',
#  'old school hip hop',
#  'old school thrash',
#  'old-time',
#  'opera',
#  'operatic pop',
#  'organic electronic',
#  'organic house',
#  'outlaw country',
#  'permanent wave',
#  'philly rap',
#  'piano blues',
#  'piano rock',
#  'piedmont blues',
#  'political hip hop',
#  'pop',
#  'pop rap',
#  'pop rock',
#  'pop soul',
#  'post-disco',
#  'post-hardcore',
#  'post-punk',
#  'power blues-rock',
#  'power pop',
#  'pre-war blues',
#  'progressive bluegrass',
#  'protest folk',
#  'protopunk',
#  'psychedelic hip hop',
#  'psychedelic rock',
#  'pub rock',
#  'punk',
#  "punk 'n' roll",
#  'punk blues',
#  'queens hip hop',
#  'quiet storm',
#  'r&b',
#  'ragtime',
#  'rap',
#  'rap kreyol',
#  'rap metal',
#  'rap rock',
#  'reggae',
#  'reggae fusion',
#  'rhythm and blues',
#  'riot grrrl',
#  'rock',
#  'rock-and-roll',
#  'rockabilly',
#  'roots reggae',
#  'roots rock',
#  'singer-songwriter',
#  'ska',
#  'ska punk',
#  'skate punk',
#  'socal pop punk',
#  'soft rock',
#  'soul',
#  'soul blues',
#  'southern hip hop',
#  'southern rock',
#  'southern soul',
#  'st louis rap',
#  'straight edge',
#  'stride',
#  'sunshine pop',
#  'supergroup',
#  'swamp pop',
#  'swamp rock',
#  'swing',
#  'synth funk',
#  'tech house',
#  'tennessee hip hop',
#  'texas blues',
#  'texas country',
#  'thrash metal',
#  'tin pan alley',
#  'torch song',
#  'traditional blues',
#  'traditional country',
#  'traditional folk',
#  'trap',
#  'trap queen',
#  'turntablism',
#  'urban contemporary',
#  'vintage jazz',
#  'virginia hip hop',
#  'vocal jazz',
#  'west coast rap',
#  'west coast trap',
#  'western swing',
#  'yacht rock',
#  'yodeling',
#  'zolo']

# %%
# Get counts of each genre and add to list of dictionaries for sorting

for_sorting = []

for i in unique_genres:
    counter = 0
    for x in genres:
        if x == i:
            counter +=1
    print(i, counter)
#     for_sorting[i] = counter
    for_sorting.append({"genre":i, "count":counter})
# Out:
# british invasion 21
# classic rock 111
# rock 101
# blues 67
# blues rock 71
# chicago blues 32
# electric blues 66
# soul 48
# traditional blues 49
# classic soul 20
# jazz blues 14
# memphis soul 12
# southern soul 15
# album rock 41
# hard rock 22
# country rock 73
# folk 28
# folk rock 41
# mellow gold 53
# roots rock 22
# singer-songwriter 22
# heartland rock 6
# permanent wave 25
# acid rock 6
# psychedelic rock 29
# baroque pop 3
# brill building pop 27
# sunshine pop 4
# beatlesque 10
# merseybeat 11
# art rock 16
# soft rock 34
# classic garage rock 3
# funk 20
# motown 14
# northern soul 3
# quiet storm 12
# adult standards 42
# disco 6
# rock-and-roll 31
# rockabilly 31
# rhythm and blues 4
# british blues 6
# indie r&b 2
# lounge 3
# glam rock 6
# protopunk 8
# bubblegum pop 8
# melancholia 1
# soul blues 26
# classic girl group 2
# southern rock 5
# swamp rock 4
# classic canadian rock 1
# grunge 1
# new wave 10
# piano blues 11
# vocal jazz 11
# freakbeat 1
# pop 3
# r&b 7
# piano rock 4
# nashville sound 29
# punk 40
# japanese jazz 1
# supergroup 1
# jazz funk 1
# post-disco 1
# australian rock 1
# metal 2
# reggae 2
# roots reggae 1
# early us punk 8
# skate punk 9
# hardcore punk 15
# california hardcore 3
# ska punk 7
# pub rock 9
# punk 'n' roll 1
# punk blues 6
# alternative rock 13
# detroit rock 3
# garage rock 3
# post-punk 11
# art punk 2
# experimental poetry 1
# madchester 2
# glam punk 1
# power pop 5
# dance rock 1
# funk rock 1
# zolo 1
# gothic rock 1
# dc hardcore 5
# noise rock 1
# post-hardcore 3
# black punk 4
# nyhc 3
# alternative metal 2
# crossover thrash 1
# funk metal 2
# nu metal 2
# old school thrash 1
# rap rock 4
# thrash metal 1
# riot grrrl 1
# northern irish punk 1
# oi 1
# ska 2
#  'country rock',
#  'blues rock',
#  'blues',
#  'electric blues',
#  'country',
#  'mellow gold',
#  'gangster rap',
#  'traditional blues',
#  'soul',
#  'east coast hip hop',
#  'adult standards',
#  'hardcore hip hop',
#  'folk rock',
#  'album rock',
#  'punk',
#  'soft rock',
#  'old school hip hop',
#  'chicago blues',
#  'rockabilly',
#  'rock-and-roll',
#  'nashville sound',
#  'modern blues',
#  'psychedelic rock',
#  'folk',
#  'pop rap',
#  'brill building pop',
#  'soul blues',
#  'permanent wave',
#  'country road',
#  'country dawn',
#  'classic country pop',
#  'golden age hip hop',
#  'singer-songwriter',
#  'hard rock',
#  'roots rock',
#  'british invasion',
#  'funk',
#  'classic soul',
#  'southern hip hop',
#  'outlaw country',
#  'electro',
#  'hip pop',
#  'contemporary country',
#  'art rock',
#  'hardcore punk',
#  'hip house',
#  'texas blues',
#  'acoustic blues',
#  'southern soul',
#  'jazz blues',
#  'motown',
#  'alternative rock',
#  'conscious hip hop',
#  'traditional country',
#  'honky tonk',
#  'quiet storm',
#  'delta blues',
#  'memphis soul',
#  'alternative hip hop',
#  'post-punk',
#  'merseybeat',
#  'country blues',
#  'piano blues',
#  'vocal jazz',
#  'arkansas country',
#  'yodeling',
#  'west coast rap',
#  'beatlesque',
#  'new wave',
#  'dance pop',
#  'country gospel',
#  'skate punk',
#  'pub rock',
#  'queens hip hop',
#  'oklahoma country',
#  'early us punk',
#  'protopunk',
#  'bubblegum pop',
#  'dirty south rap',
#  'trap',
#  'r&b',
#  'urban contemporary',
#  'ska punk',
#  'g funk',
#  'harmonica blues',
#  'modern blues rock',
#  'new jack swing',
#  'punk blues',
#  'british blues',
#  'glam rock',
#  'disco',
#  'heartland rock',
#  'acid rock',
#  'political hip hop',
#  'atl hip hop',
#  'harlem hip hop',
#  'jazz rap',
#  'texas country',
#  'new jersey rap',
#  'bronx hip hop',
#  'cowboy western',
#  'memphis blues',
#  'power pop',
#  'southern rock',
#  'dc hardcore',
#  'rhythm and blues',
#  'jump blues',
#  'rap rock',
#  'swamp rock',
#  'black punk',
#  'bakersfield sound',
#  'sunshine pop',
#  'lilith',
#  'piano rock',
#  'turntablism',
#  'miami bass',
#  'crunk',
#  'neo soul',
#  'garage rock',
#  'pop',
#  'lounge',
#  'canadian country',
#  'canadian pop',
#  'bluegrass gospel',
#  'detroit rock',
#  'california hardcore',
#  'classic garage rock',
#  'nyhc',
#  'baroque pop',
#  'post-hardcore',
#  'northern soul',
#  'cosmic american',
#  'appalachian folk',
#  'traditional folk',
#  'madchester',
#  'new orleans rap',
#  'piedmont blues',
#  'double drumming',
#  'art punk',
#  'jam band',
#  'houston rap',
#  'metal',
#  'boogie-woogie',
#  'miami hip hop',
#  'reggae',
#  'alternative metal',
#  'instrumental rock',
#  'funk metal',
#  'ska',
#  'alternative pop',
#  'chicano rap',
#  'new wave pop',
#  'easy listening',
#  'chicago rap',
#  'progressive bluegrass',
#  'new orleans blues',
#  'country boogie',
#  'torch song',
#  'nu metal',
#  'bluegrass',
#  'harlem renaissance',
#  'classic girl group',
#  'louisiana blues',
#  'power blues-rock',
#  'indie r&b',
#  'philly rap',
#  'swing',
#  'big band',
#  'organic house',
#  'tech house',
#  'ohio hip hop',
#  'afrofuturism',
#  'psychedelic hip hop',
#  'beatboxing',
#  'reggae fusion',
#  'oakland hip hop',
#  'st louis rap',
#  'cali rap',
#  'hyphy',
#  'northern irish punk',
#  'grunge',
#  'pop soul',
#  'melancholia',
#  'new mexico music',
#  'kentucky roots',
#  'operatic pop',
#  'irish folk',
#  'celtic rock',
#  'celtic',
#  'western swing',
#  'old-time',
#  'classic canadian rock',
#  'trap queen',
#  'minimal techno',
#  'freakbeat',
#  'chopped and screwed',
#  'battle rap',
#  'rap kreyol',
#  'tennessee hip hop',
#  'memphis hip hop',
#  'dubstep product',
#  'organic electronic',
#  'west coast trap',
#  'minimal tech house',
#  'microhouse',
#  'modern alternative rock',
#  'crossover thrash',
#  'vintage jazz',
#  'stride',
#  'ragtime',
#  'new orleans jazz',
#  'jazz trumpet',
#  'dixieland',
#  'old school thrash',
#  'pre-war blues',
#  'thrash metal',
#  'riot grrrl',
#  'classical saxophone',
#  'opera',
#  'classical performance',
#  'classical mezzo-soprano',
#  'choral',
#  'lo-fi',
#  'freak folk',
#  'boston rock',
#  'anti-folk',
#  'candy pop',
#  'gbvfi',
#  'pop rock',
#  'indie rock',
#  'straight edge',
#  'socal pop punk',
#  'american folk revival',
#  'protest folk',
#  'yacht rock',
#  'synth funk',
#  'israeli techno',
#  'bboy',
#  'japanese jazz',
#  'supergroup',
#  'rap metal',
#  'jazz funk',
#  'virginia hip hop',
#  'detroit hip hop',
#  'post-disco',
#  'australian rock',
#  'girl group',
#  'roots reggae',
#  'oi',
#  'american modern classical',
#  "punk 'n' roll",
#  'experimental poetry',
#  'glam punk',
#  'dance rock',
#  'funk rock',
#  'zolo',
#  'gothic rock',
#  'noise rock',
#  'gospel singers',
#  'tin pan alley',
#  'early modern classical',
#  'classical',
#  'swamp pop']

# %%
# Create finction to get most general genre for song/artist
def get_general_genre(x):
    for genre in sorted_genres:
        for artist_genre in x:
            if artist_genre == genre:
                return(artist_genre)

# %%
# Create column for most general genre

df["general_genre"] = df["artist_genre(s)"].apply(get_general_genre)

# %% [markdown]
# #### Clean Data, Tokenize, and Remove Stop Words

# %%
# Create fucntion to remove errors and "\n" from lyric strings

def remove_lyric_errors(x):
    x = re.sub('\n', ' ', x)
    x = re.sub(',', '', x)
    x = re.sub(';', '', x)
    x = x.lower()
    return(x)

# %%
# apply function
df["lyrics"] = df.lyrics.apply(remove_lyric_errors)

# %%
df.head(10)
# Out:
#                    song              artist       genius_artist  \
# 0          Satisfaction  The Rolling Stones  The Rolling Stones
# 1               Respect     Aretha Franklin     Aretha Franklin
# 2    Stairway to Heaven        Led Zeppelin        Led Zeppelin
# 3  Like a Rolling Stone           Bob Dylan           Bob Dylan
# 4           Born to Run   Bruce Springsteen   Bruce Springsteen
# 5      Hotel California          The Eagles        Genius Lists
# 6         Light My Fire           The Doors           The Doors
# 7       Good Vibrations      The Beach Boys      The Beach Boys
# 8              Hey Jude         The Beatles         The Beatles
# 9               Imagine         John Lennon         John Lennon
#
#        spotify_artist               artist_id album  \
# 0  The Rolling Stones  22bE4uQ6baNwSHPVcDxLCe
# 1     Aretha Franklin  7nwUJBm0HE4ZxD3f5cy5ok
# 2        Led Zeppelin  36QJpDe2go2KgaRleHCDTp
# 3           Bob Dylan  74ASZWbe4lXaubB36ztrGX
# 4   Bruce Springsteen  3eqjTLE0HfPfh78zjh6TqT
# 5
# 6           The Doors  22WZ7M8sxp5THdruNY3gXt
# 7      The Beach Boys  3oDbviiivRWhXwIE8hxkVV
# 8         The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 9         John Lennon  4x1nvY2FN8jxqAFA0DA02H
#
#                                      artist_genre(s)  \
# 0  [british invasion, classic rock, rock, blues, ...
# 1  [classic soul, jazz blues, memphis soul, soul,...
# 2        [album rock, classic rock, hard rock, rock]
# 3  [album rock, classic rock, country rock, folk,...
# 4  [classic rock, heartland rock, mellow gold, pe...
# 5                                                 []
# 6  [acid rock, classic rock, psychedelic rock, rock]
# 7  [baroque pop, brill building pop, classic rock...
# 8  [beatlesque, british invasion, classic rock, m...
# 9  [album rock, art rock, beatlesque, classic roc...
#
#                                               lyrics audio_features
# 0  i can't get no satisfaction i can't get no sat...             {}
# 1  what you want baby i got it what you need do y...             {}
# 2  there's a lady who's sure all that glitters is...             {}
# 3  once upon a time you dressed so fine threw the...             {}
# 4  in the day we sweat it out on the streets of a...             {}
# 5  in alphabetical order by title: can't find you...             {}
# 6  you know that it would be untrue you know that...             {}
# 7  i-i love the colorful clothes she wears and th...             {}
# 8  hey jude don't make it bad take a sad song and...             {}
# 9  imagine there's no heaven it's easy if you try...             {}

# %%
# Create copy for manipulation
df_tokens = df.copy()

# %%
# Tokenize lyrics
# df_tokens["lyrics_tokenized"] = df_tokens.lyrics.apply(lambda x: word_tokenize(x))
df_tokens["lyrics_tokenized"] = df_tokens.lyrics.apply(lambda x: x.split())

# %%
df_tokens.head(10)
# Out:
#                    song              artist       genius_artist  \
# 0          Satisfaction  The Rolling Stones  The Rolling Stones
# 1               Respect     Aretha Franklin     Aretha Franklin
# 2    Stairway to Heaven        Led Zeppelin        Led Zeppelin
# 3  Like a Rolling Stone           Bob Dylan           Bob Dylan
# 4           Born to Run   Bruce Springsteen   Bruce Springsteen
# 5      Hotel California          The Eagles        Genius Lists
# 6         Light My Fire           The Doors           The Doors
# 7       Good Vibrations      The Beach Boys      The Beach Boys
# 8              Hey Jude         The Beatles         The Beatles
# 9               Imagine         John Lennon         John Lennon
#
#        spotify_artist               artist_id album  \
# 0  The Rolling Stones  22bE4uQ6baNwSHPVcDxLCe
# 1     Aretha Franklin  7nwUJBm0HE4ZxD3f5cy5ok
# 2        Led Zeppelin  36QJpDe2go2KgaRleHCDTp
# 3           Bob Dylan  74ASZWbe4lXaubB36ztrGX
# 4   Bruce Springsteen  3eqjTLE0HfPfh78zjh6TqT
# 5
# 6           The Doors  22WZ7M8sxp5THdruNY3gXt
# 7      The Beach Boys  3oDbviiivRWhXwIE8hxkVV
# 8         The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 9         John Lennon  4x1nvY2FN8jxqAFA0DA02H
#
#                                      artist_genre(s)  \
# 0  [british invasion, classic rock, rock, blues, ...
# 1  [classic soul, jazz blues, memphis soul, soul,...
# 2        [album rock, classic rock, hard rock, rock]
# 3  [album rock, classic rock, country rock, folk,...
# 4  [classic rock, heartland rock, mellow gold, pe...
# 5                                                 []
# 6  [acid rock, classic rock, psychedelic rock, rock]
# 7  [baroque pop, brill building pop, classic rock...
# 8  [beatlesque, british invasion, classic rock, m...
# 9  [album rock, art rock, beatlesque, classic roc...
#
#                                               lyrics audio_features  \
# 0  I can't get no satisfaction I can't get no sat...             {}
# 1  What you want baby I got it What you need do y...             {}
# 2  There's a lady who's sure all that glitters is...             {}
# 3  Once upon a time you dressed so fine Threw the...             {}
# 4  In the day we sweat it out on the streets Of a...             {}
# 5  Can't find your song?  Please add it and link ...             {}
# 6  You know that it would be untrue You know that...             {}
# 7  I-I love the colorful clothes she wears And th...             {}
# 8  Hey Jude don't make it bad Take a sad song and...             {}
# 9  Imagine there's no heaven It's easy if you try...             {}
#
#                                     lyrics_tokenized  \
# 0  [I, can't, get, no, satisfaction, I, can't, ge...
# 1  [What, you, want, baby, I, got, it, What, you,...
# 2  [There's, a, lady, who's, sure, all, that, gli...
# 3  [Once, upon, a, time, you, dressed, so, fine, ...
# 4  [In, the, day, we, sweat, it, out, on, the, st...
# 5  [Can't, find, your, song?, Please, add, it, an...
# 6  [You, know, that, it, would, be, untrue, You, ...
# 7  [I-I, love, the, colorful, clothes, she, wears...
# 8  [Hey, Jude, don't, make, it, bad, Take, a, sad...
# 9  [Imagine, there's, no, heaven, It's, easy, if,...
#
#                                  lyrics_wo_stopwords
# 0  [I, can't, get, satisfaction, I, can't, get, s...
# 1  [What, want, baby, I, got, What, need, know, I...
# 2  [There's, lady, who's, sure, glitters, gold, A...
# 3  [Once, upon, time, dressed, fine, Threw, bums,...
# 4  [In, day, sweat, streets, Of, runaway, America...
# 5  [Can't, find, song?, Please, add, link, it!, A...
# 6  [You, know, would, untrue, You, know, I, would...
# 7  [I-I, love, colorful, clothes, wears, And, way...
# 8  [Hey, Jude, make, bad, Take, sad, song, make, ...
# 9  [Imagine, there's, heaven, It's, easy, try, No...

# %%
def remove_stopwords(list_of_words):
    stop_words = set(stopwords.words('english'))
    tokens_without_sw = [word for word in list_of_words if not word in stop_words]
    return tokens_without_sw

# %%
# Remove stopwords
df_tokens["lyrics_wo_stopwords"] = df_tokens.lyrics_tokenized.apply(remove_stopwords)

# %%
df_tokens
# Out:
#                                   song                    artist  \
# 0                         Satisfaction        The Rolling Stones
# 1                              Respect           Aretha Franklin
# 2                   Stairway to Heaven              Led Zeppelin
# 3                 Like a Rolling Stone                 Bob Dylan
# 4                          Born to Run         Bruce Springsteen
# ..                                 ...                       ...
# 433  I'D Be Better Off (In a Pine Box)                Doug Stone
# 434                             Amazed                  Lonestar
# 435                         Faded Love  Bob Wills or Patsy Cline
# 436           Back in the Saddle Again                Gene Autry
# 437                       Killin' Time               Clint Black
#
#           genius_artist      spotify_artist               artist_id album  \
# 0    The Rolling Stones  The Rolling Stones  22bE4uQ6baNwSHPVcDxLCe
# 1       Aretha Franklin     Aretha Franklin  7nwUJBm0HE4ZxD3f5cy5ok
# 2          Led Zeppelin        Led Zeppelin  36QJpDe2go2KgaRleHCDTp
# 3             Bob Dylan           Bob Dylan  74ASZWbe4lXaubB36ztrGX
# 4     Bruce Springsteen   Bruce Springsteen  3eqjTLE0HfPfh78zjh6TqT
# ..                  ...                 ...                     ...   ...
# 433          Doug Stone          Doug Stone  4epBFW4UHEmgjIK5xOrBhk
# 434            Lonestar            Lonestar  3qbnxnvUqR14MJ9g8QwZJK
# 435      Country Genius
# 436          Gene Autry          Gene Autry  5ixB75BQR3ADoWQkcHQJTs
# 437         Clint Black         Clint Black  3Ay15wt0QChT4Kapsuw5Jt
#
#                                        artist_genre(s)  \
# 0    [british invasion, classic rock, rock, blues, ...
# 1    [classic soul, jazz blues, memphis soul, soul,...
# 2          [album rock, classic rock, hard rock, rock]
# 3    [album rock, classic rock, country rock, folk,...
# 4    [classic rock, heartland rock, mellow gold, pe...
# ..                                                 ...
# 433              [country, country road, country rock]
# 434      [contemporary country, country, country road]
# 435                                                 []
# 436  [adult standards, cowboy western, oklahoma cou...
# 437              [country, country road, country rock]
#
#                                                 lyrics audio_features  \
# 0    I can't get no satisfaction I can't get no sat...             {}
# 1    What you want baby I got it What you need do y...             {}
# 2    There's a lady who's sure all that glitters is...             {}
# 3    Once upon a time you dressed so fine Threw the...             {}
# 4    In the day we sweat it out on the streets Of a...             {}
# ..                                                 ...            ...
# 433  Well I said the night you left me nothin' wors...             {}
# 434  Every time our eyes meet This feeling inside m...             {}
# 435  The Nashville Basin and Country MusicMusic has...             {}
# 436  I'm back in the saddle again Out where a frien...             {}
# 437  You were the first thing that I thought of Whe...             {}
#
#                                       lyrics_tokenized  \
# 0    [I, can't, get, no, satisfaction, I, can't, ge...
# 1    [What, you, want, baby, I, got, it, What, you,...
# 2    [There's, a, lady, who's, sure, all, that, gli...
# 3    [Once, upon, a, time, you, dressed, so, fine, ...
# 4    [In, the, day, we, sweat, it, out, on, the, st...
# ..                                                 ...
# 433  [Well, I, said, the, night, you, left, me, not...
# 434  [Every, time, our, eyes, meet, This, feeling, ...
# 435  [The, Nashville, Basin, and, Country, MusicMus...
# 436  [I'm, back, in, the, saddle, again, Out, where...
# 437  [You, were, the, first, thing, that, I, though...
#
#                                    lyrics_wo_stopwords
# 0    [I, can't, get, satisfaction, I, can't, get, s...
# 1    [What, want, baby, I, got, What, need, know, I...
# 2    [There's, lady, who's, sure, glitters, gold, A...
# 3    [Once, upon, time, dressed, fine, Threw, bums,...
# 4    [In, day, sweat, streets, Of, runaway, America...
# ..                                                 ...
# 433  [Well, I, said, night, left, nothin', worse, c...
# 434  [Every, time, eyes, meet, This, feeling, insid...
# 435  [The, Nashville, Basin, Country, MusicMusic, b...
# 436  [I'm, back, saddle, Out, friend, friend, Where...
# 437  [You, first, thing, I, thought, When, I, thoug...
#
# [438 rows x 11 columns]
